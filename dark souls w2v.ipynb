# %%
import pandas as pd
import numpy as np

# %%
pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gensim
#   Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in C:\ProgramData\anaconda3\Lib\site-packages (from gensim) (2.1.3)
# Requirement already satisfied: scipy>=1.7.0 in C:\ProgramData\anaconda3\Lib\site-packages (from gensim) (1.15.3)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.5.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in C:\ProgramData\anaconda3\Lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 1.2 MB/s eta 0:00:21
#    - -------------------------------------- 0.8/24.4 MB 1.1 MB/s eta 0:00:21
#    - -------------------------------------- 1.0/24.4 MB 1.1 MB/s eta 0:00:21
#    - -------------------------------------- 1.0/24.4 MB 1.1 MB/s eta 0:00:21
#    -- ------------------------------------- 1.3/24.4 MB 1.0 MB/s eta 0:00:23
#    -- ------------------------------------- 1.6/24.4 MB 1.0 MB/s eta 0:00:23
#    --- ------------------------------------ 1.8/24.4 MB 1.1 MB/s eta 0:00:21
#    --- ------------------------------------ 2.1/24.4 MB 1.1 MB/s eta 0:00:21
#    --- ------------------------------------ 2.4/24.4 MB 1.1 MB/s eta 0:00:20
#    ---- ----------------------------------- 2.6/24.4 MB 1.1 MB/s eta 0:00:20
#    ---- ----------------------------------- 2.9/24.4 MB 1.1 MB/s eta 0:00:20
#    ----- ---------------------------------- 3.1/24.4 MB 1.1 MB/s eta 0:00:20
#    ----- ---------------------------------- 3.4/24.4 MB 1.1 MB/s eta 0:00:20
#    ----- ---------------------------------- 3.4/24.4 MB 1.1 MB/s eta 0:00:20
#    ------ --------------------------------- 3.7/24.4 MB 1.1 MB/s eta 0:00:19
#    ------ --------------------------------- 3.9/24.4 MB 1.1 MB/s eta 0:00:19
#    ------ --------------------------------- 4.2/24.4 MB 1.1 MB/s eta 0:00:19
#    ------- -------------------------------- 4.5/24.4 MB 1.1 MB/s eta 0:00:19
#    ------- -------------------------------- 4.7/24.4 MB 1.1 MB/s eta 0:00:18
#    -------- ------------------------------- 5.0/24.4 MB 1.1 MB/s eta 0:00:18
#    -------- ------------------------------- 5.2/24.4 MB 1.1 MB/s eta 0:00:18
#    --------- ------------------------------ 5.5/24.4 MB 1.1 MB/s eta 0:00:18
#    --------- ------------------------------ 5.5/24.4 MB 1.1 MB/s eta 0:00:18
#    --------- ------------------------------ 5.8/24.4 MB 1.1 MB/s eta 0:00:17
#    --------- ------------------------------ 6.0/24.4 MB 1.1 MB/s eta 0:00:17
#    ---------- ----------------------------- 6.3/24.4 MB 1.1 MB/s eta 0:00:17
#    ---------- ----------------------------- 6.6/24.4 MB 1.1 MB/s eta 0:00:17
#    ----------- ---------------------------- 6.8/24.4 MB 1.1 MB/s eta 0:00:17
#    ----------- ---------------------------- 7.1/24.4 MB 1.1 MB/s eta 0:00:16
#    ------------ --------------------------- 7.3/24.4 MB 1.1 MB/s eta 0:00:16
#    ------------ --------------------------- 7.6/24.4 MB 1.1 MB/s eta 0:00:16
#    ------------ --------------------------- 7.6/24.4 MB 1.1 MB/s eta 0:00:16
#    ------------ --------------------------- 7.9/24.4 MB 1.1 MB/s eta 0:00:16
#    ------------- -------------------------- 8.1/24.4 MB 1.1 MB/s eta 0:00:15
#    ------------- -------------------------- 8.4/24.4 MB 1.1 MB/s eta 0:00:15
#    -------------- ------------------------- 8.7/24.4 MB 1.1 MB/s eta 0:00:15
#    -------------- ------------------------- 8.9/24.4 MB 1.1 MB/s eta 0:00:15
#    --------------- ------------------------ 9.2/24.4 MB 1.1 MB/s eta 0:00:14
#    --------------- ------------------------ 9.2/24.4 MB 1.1 MB/s eta 0:00:14
#    --------------- ------------------------ 9.4/24.4 MB 1.1 MB/s eta 0:00:14
#    --------------- ------------------------ 9.7/24.4 MB 1.1 MB/s eta 0:00:14
#    --------------- ------------------------ 9.7/24.4 MB 1.1 MB/s eta 0:00:14
#    ---------------- ----------------------- 10.0/24.4 MB 1.1 MB/s eta 0:00:14
#    ---------------- ----------------------- 10.0/24.4 MB 1.1 MB/s eta 0:00:14
#    ---------------- ----------------------- 10.2/24.4 MB 1.1 MB/s eta 0:00:14
#    ----------------- ---------------------- 10.5/24.4 MB 1.1 MB/s eta 0:00:14
#    ----------------- ---------------------- 10.7/24.4 MB 1.1 MB/s eta 0:00:13
#    ----------------- ---------------------- 10.7/24.4 MB 1.1 MB/s eta 0:00:13
#    ------------------ --------------------- 11.0/24.4 MB 1.0 MB/s eta 0:00:13
#    ------------------ --------------------- 11.0/24.4 MB 1.0 MB/s eta 0:00:13
#    ------------------ --------------------- 11.3/24.4 MB 1.0 MB/s eta 0:00:13
#    ------------------ --------------------- 11.5/24.4 MB 1.0 MB/s eta 0:00:13
#    ------------------- -------------------- 11.8/24.4 MB 1.0 MB/s eta 0:00:13
#    ------------------- -------------------- 12.1/24.4 MB 1.0 MB/s eta 0:00:12
#    -------------------- ------------------- 12.3/24.4 MB 1.0 MB/s eta 0:00:12
#    -------------------- ------------------- 12.6/24.4 MB 1.0 MB/s eta 0:00:12
#    -------------------- ------------------- 12.6/24.4 MB 1.0 MB/s eta 0:00:12
#    --------------------- ------------------ 12.8/24.4 MB 1.0 MB/s eta 0:00:12
#    --------------------- ------------------ 13.1/24.4 MB 1.0 MB/s eta 0:00:11
#    --------------------- ------------------ 13.4/24.4 MB 1.0 MB/s eta 0:00:11
#    ---------------------- ----------------- 13.6/24.4 MB 1.0 MB/s eta 0:00:11
#    ---------------------- ----------------- 13.9/24.4 MB 1.0 MB/s eta 0:00:11
#    ----------------------- ---------------- 14.2/24.4 MB 1.0 MB/s eta 0:00:10
#    ----------------------- ---------------- 14.4/24.4 MB 1.0 MB/s eta 0:00:10
#    ----------------------- ---------------- 14.4/24.4 MB 1.0 MB/s eta 0:00:10
#    ------------------------ --------------- 14.7/24.4 MB 1.0 MB/s eta 0:00:10
#    ------------------------ --------------- 14.9/24.4 MB 1.0 MB/s eta 0:00:10
#    ------------------------ --------------- 15.2/24.4 MB 1.0 MB/s eta 0:00:09
#    ------------------------- -------------- 15.5/24.4 MB 1.0 MB/s eta 0:00:09
#    ------------------------- -------------- 15.7/24.4 MB 1.0 MB/s eta 0:00:09
#    -------------------------- ------------- 16.0/24.4 MB 1.0 MB/s eta 0:00:09
#    -------------------------- ------------- 16.0/24.4 MB 1.0 MB/s eta 0:00:09
#    -------------------------- ------------- 16.3/24.4 MB 1.0 MB/s eta 0:00:08
#    --------------------------- ------------ 16.5/24.4 MB 1.0 MB/s eta 0:00:08
#    --------------------------- ------------ 16.8/24.4 MB 1.0 MB/s eta 0:00:08
#    --------------------------- ------------ 17.0/24.4 MB 1.0 MB/s eta 0:00:08
#    --------------------------- ------------ 17.0/24.4 MB 1.0 MB/s eta 0:00:08
#    ---------------------------- ----------- 17.3/24.4 MB 1.0 MB/s eta 0:00:07
#    ---------------------------- ----------- 17.6/24.4 MB 1.0 MB/s eta 0:00:07
#    ----------------------------- ---------- 17.8/24.4 MB 1.0 MB/s eta 0:00:07
#    ----------------------------- ---------- 17.8/24.4 MB 1.0 MB/s eta 0:00:07
#    ----------------------------- ---------- 18.1/24.4 MB 1.0 MB/s eta 0:00:07
#    ------------------------------ --------- 18.4/24.4 MB 1.0 MB/s eta 0:00:06
#    ------------------------------ --------- 18.6/24.4 MB 1.0 MB/s eta 0:00:06
#    ------------------------------ --------- 18.9/24.4 MB 1.0 MB/s eta 0:00:06
#    ------------------------------- -------- 19.1/24.4 MB 1.0 MB/s eta 0:00:06
#    ------------------------------- -------- 19.1/24.4 MB 1.0 MB/s eta 0:00:06
#    ------------------------------- -------- 19.1/24.4 MB 1.0 MB/s eta 0:00:06
#    ------------------------------- -------- 19.4/24.4 MB 1.0 MB/s eta 0:00:05
#    ------------------------------- -------- 19.4/24.4 MB 1.0 MB/s eta 0:00:05
#    -------------------------------- ------- 19.7/24.4 MB 1.0 MB/s eta 0:00:05
#    -------------------------------- ------- 19.7/24.4 MB 1.0 MB/s eta 0:00:05
#    -------------------------------- ------- 19.9/24.4 MB 1.0 MB/s eta 0:00:05
#    --------------------------------- ------ 20.2/24.4 MB 1.0 MB/s eta 0:00:05
#    --------------------------------- ------ 20.4/24.4 MB 1.0 MB/s eta 0:00:04
#    --------------------------------- ------ 20.7/24.4 MB 1.0 MB/s eta 0:00:04
#    ---------------------------------- ----- 21.0/24.4 MB 1.0 MB/s eta 0:00:04
#    ---------------------------------- ----- 21.2/24.4 MB 1.0 MB/s eta 0:00:04
#    ---------------------------------- ----- 21.2/24.4 MB 1.0 MB/s eta 0:00:04
#    ----------------------------------- ---- 21.5/24.4 MB 1.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.8/24.4 MB 1.0 MB/s eta 0:00:03
#    ------------------------------------ --- 22.0/24.4 MB 1.0 MB/s eta 0:00:03
#    ------------------------------------ --- 22.3/24.4 MB 1.0 MB/s eta 0:00:03
#    ------------------------------------ --- 22.5/24.4 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 22.8/24.4 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 23.1/24.4 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 23.1/24.4 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 23.3/24.4 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 23.6/24.4 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  23.9/24.4 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  24.1/24.4 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 1.0 MB/s  0:00:23
# Downloading smart_open-7.5.1-py3-none-any.whl (64 kB)
# Installing collected packages: smart_open, gensim
#
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    ---------------------------------------- 2/2 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('dataset'):
    f = open(os.path.join('dataset' , filename))
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 461

# %%
model = gensim.models.Word2Vec(
    window = 4,
    min_count = 2
)

# %%
model.build_vocab(story)

# %%
model.train(story , total_examples = model.corpus_count , epochs = model.epochs)
# Out:
# (28379, 47260)

# %%
model.wv.most_similar('solaire')
# Out:
# [('lordran', 0.9851850867271423),
#  ('fire', 0.9846551418304443),
#  ('for', 0.98452228307724),
#  ('by', 0.9845043420791626),
#  ('armor', 0.98448246717453),
#  ('of', 0.9843828082084656),
#  ('it', 0.9843779802322388),
#  ('was', 0.9841282367706299),
#  ('they', 0.9840469360351562),
#  ('the', 0.9839863181114197)]

# %%
 model.wv['knight']
# Out:
# array([-0.10766818,  0.13171802,  0.01534864, -0.02531723,  0.05952979,
#        -0.17453969,  0.08184815,  0.26136652, -0.11987285, -0.11254461,
#        -0.02675057, -0.1697569 , -0.0497556 ,  0.08548925,  0.05246987,
#        -0.06561501,  0.05370382, -0.06550912, -0.0680748 , -0.24911463,
#        -0.00259336,  0.02411578,  0.11268677,  0.01163736, -0.06208842,
#         0.00418744, -0.05979101, -0.06026547, -0.11350817,  0.04008076,
#         0.15731473, -0.01595555,  0.06962959, -0.11130559, -0.04753476,
#         0.12363229,  0.00575727, -0.08910176, -0.08411456, -0.18192713,
#         0.05065055, -0.0972854 , -0.02679291,  0.00870956,  0.06982554,
#        -0.01143776, -0.07621182, -0.0310407 ,  0.00993387,  0.10448927,
#         0.03506469, -0.11271355, -0.03563547,  0.00102335, -0.09963717,
#         0.01893391,  0.07227933, -0.0261667 , -0.18264697,  0.03003232,
#         0.10244811,  0.04381929,  0.04597988, -0.00398908, -0.11958033,
#         0.10429478,  0.10912271,  0.13288778, -0.1858333 ,  0.1664244 ,
#        -0.01784926,  0.06590354,  0.12648636,  0.00886955,  0.16838282,
#         0.05095561, -0.00809329,  0.03209234, -0.1032499 ,  0.03871474,
#        -0.05715687, -0.04302348, -0.12685125,  0.12918697, -0.01141557,
#        -0.0114043 ,  0.04079413,  0.16748749,  0.09113888,  0.01065689,
#         0.15099525,  0.07626794,  0.03004687, -0.00113828,  0.19192739,
#         0.12726493,  0.12893756, -0.12533732,  0.05150777, -0.00535257],
#       dtype=float32)

# %%
model.wv.doesnt_match(['astora' , 'solaire' , 'knight' , 'patches'])
# Out:
# 'patches'
