# %%
import pandas as pd
import numpy as np

# %%
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('archive'):
    f = open(os.path.join('archive' , filename))
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145020

# %%
model = gensim.models.Word2Vec(
    window = 8,
    min_count = 2
)

# %%
model.build_vocab(story)

# %%
model.train(story , total_examples = model.corpus_count , epochs = model.epochs)
# Out:
# (6570293, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('targaryen', 0.7326015830039978),
#  ('myrcella', 0.7216731905937195),
#  ('margaery', 0.7193173170089722),
#  ('stormborn', 0.7167065739631653),
#  ('princess', 0.7134031653404236),
#  ('elia', 0.7055533528327942),
#  ('viserys', 0.6856504082679749),
#  ('queen', 0.6758652925491333),
#  ('cersei', 0.6575721502304077),
#  ('rhaegar', 0.6544790267944336)]

# %%
model.wv['king']
# Out:
# array([ 9.4637662e-01, -5.6143034e-01,  1.1708592e+00,  1.5350832e+00,
#        -1.6311839e+00,  3.3706195e+00,  4.9197546e-01, -4.0690917e-01,
#        -1.7665980e+00, -9.9340089e-02, -1.5360138e+00, -7.0515461e-02,
#        -5.1281714e-01,  2.6278999e+00, -2.2687175e+00, -4.7166038e-01,
#         1.1068152e+00,  2.7054408e+00,  1.3099235e+00,  1.1054698e+00,
#         1.3837445e+00, -1.8257378e+00,  2.7993076e+00, -2.0621312e+00,
#        -1.3744817e+00,  9.5284367e-01, -2.0845022e+00, -8.6562598e-01,
#        -2.6353612e+00,  1.4495251e+00, -2.9071290e+00,  7.8033012e-01,
#         4.9320149e-01, -5.5886632e-01,  2.1211874e+00, -2.0730939e+00,
#        -1.4360782e+00, -1.3383431e+00,  8.0855870e-01, -1.0742968e+00,
#         5.1280415e-01,  1.4018488e+00,  2.3736544e+00, -5.1027626e-01,
#        -1.3541660e+00, -1.4345499e+00,  1.8292341e-01, -1.0744406e+00,
#         1.6938808e+00, -3.0464756e+00, -3.1364841e+00, -9.8863536e-01,
#        -1.5512822e+00, -2.6356101e+00,  4.2325654e+00, -2.5947356e+00,
#        -1.7667673e+00,  9.2994976e-01,  1.2294126e+00,  1.1864552e+00,
#         1.5145309e+00,  1.7654111e+00, -3.7853271e-01,  6.7129187e-02,
#         3.6730957e-01,  5.6190372e-01,  4.3850103e-01, -4.8343629e-01,
#         2.9821214e-01, -1.6861892e+00,  1.4412664e+00, -4.2399240e-01,
#         3.4671352e+00, -2.3079786e+00,  2.1946833e+00,  1.0727946e+00,
#        -8.3551586e-01, -1.8655460e+00,  2.0971639e-01, -2.9625809e+00,
#        -3.8380405e-01,  1.8547105e+00, -2.5441241e+00,  7.7456236e-01,
#        -4.5121770e+00, -2.3024974e+00,  9.5120394e-01,  2.0933664e+00,
#         2.8917885e+00, -1.9442838e-01,  1.3144113e+00,  1.9028929e+00,
#         2.5391215e-03, -3.1336191e+00,  1.5690526e+00, -1.3154941e+00,
#        -2.2587550e-01,  1.0982486e+00,  1.3344789e+00,  6.1099726e-01],
#       dtype=float32)

# %%
model.wv.doesnt_match(['king' , 'dragon' , 'daenery' , 'throne'])
# Out:
# 'dragon'
